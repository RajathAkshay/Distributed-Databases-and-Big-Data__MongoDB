# %% [markdown]
# # Distributed Databases and Big Data
#
# - Rajath Akshay Vanikul
#
# ### Background
# StopFire is a campaign started by Monash University to predict and stop the fire in Victorian cities. They have employed sensors in different cities of Victoria and have collected a large amount of data. The data is so big that their techniques have failed to provide the results on time to predict fire. We are asked to migrate their data to the NoSQL database (MongoDB).We also analyse the data to provide them with results. In addition, we will build an application, a complete setup from streaming to storing and analyzing the data for them using Apache Kafka, Apache Spark Streaming and MongoDB.

# %% [markdown]
# ## Task A
# ## MongoDB Data Model
#
# Based on the two data sets provided i.e. `hotspot_historic.csv` and `climate_historic.csv`, we have designed a suitable data model to support the efficient storing and querying of the two data sets in MongoDB.
#
# We know that the climate and fire data will be gathered in large quantities over the years whcih makes us think about a model which is easy to scale and yet have a distinguised event entities among different collections in database. We will be using model similar to [Anchor Modeling](https://en.wikipedia.org/wiki/Anchor_modeling)(reference model) but modify it according to our requirement.
#
# Our data model adresses the following:
# * high scalability.
# * avoid null values.
# * keep the information free from redundancies.
# * being able to non-destructively evolve the model.
#
# However, the only downside of our data model is that it increases the number of join query operations. We believes that analysis and query in a climate and hotspot data are performed only based on a small section of fields. This is similar to the array storage structure, which can significantly reduce data scanning and reduce the impact on query performance. Mongo DB is one of those databases with the table elimination feature that can greatly reduce the number of join operations.

# %%
# import the following libraries to perform this task.
from pymongo import MongoClient # access mongoDb using python.
import datetime 
import pandas as pd
from datetime import datetime
import dateutil.parser
import pymongo

# %%
# instantiating mongo client.
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# instantiating the database
mydb = myclient["assignment2"]

# %%
# instantiating the collections in the created database.
climate_collection = mydb["climate"] # collection named "climate"
fire_collection = mydb["fire"] # collection names "fire"

# %% [markdown]
# ### schema creation
# Creating the schema to validate the structure and declare the datatype of each entry.
# Below is the code that addresses the schema for climate and fire collections in the data base.

# %%
# schema to validate the climate collection.
validator_schema_climate = {"$jsonSchema":
  {
         "bsonType": "object",
         "required": [ "station", "date", "air_temperature_celcius", "relative_humidity","windspeed_knots","max_wind_speed","precipitation"],
         "properties": {
            "station": {
               "bsonType": "int",
               "description": "must be an integer and is required"
            },
            "date": {
               "bsonType": "timestamp",
               "description": "must be a date and is not required"
            },
            "air_temperature_celcius": {
               "bsonType": "int",
               "description": "must be an integer and is required"
            },
            "relative_humidity": {
               "bsonType": "double",
               "description": "can only be double and is required"
            },
            "windspeed_knots": {
               "bsonType": ["double"],
               "description": "must be a double and is required"
            },
             "max_wind_speed": {
               "bsonType": [ "double" ],
               "description": "must be a double and is required"
            },
             "precipitation ": {
               "bsonType": "object",
               "description": "must be a string and is required"
            }
         }
  }
}

# %%
# schema to validate the fire collection.
validator_schema_fire = {"$jsonSchema":
  {
         "bsonType": "object",
         "required": [ "latitude", "longitude", "surface_temperature_celcius", "confidence","datetime","date"],
         "properties": {
            "latitude": {
               "bsonType": "double",
               "description": "must be an integer and is required"
            },
            "datetime": {
               "bsonType": "timestamp",
               "description": "must be a date and is not required"
            },
            "date": {
               "bsonType": "timestamp",
               "description": "must be a date and is not required"
            },
            "longitude": {
               "bsonType": "double",
               "description": "must be an integer and is required"
            },
            "surface_temperature_celcius": {
               "bsonType": "int",
               "description": "can only be int and is required"
            },
            "confidence": {
               "bsonType": "int",
               "description": "must be a int and is required"
            }
         }
  }
}

# %% [markdown]
# **Example for climate data model:**
#
# `
# {
#     '_id': ObjectId('5ce7568aa90b9bcb3df7ffb4'),
#     'station': 948700,
#     'date': datetime.datetime(2016, 12, 31, 0, 0),
#     'air_temperature_celcius': 19,
#     'relative_humidity': 56.8,
#     'windspeed_knots': 7.9,
#     'max_wind_speed': 11.1,
#     'precipitation ': ' 0.00I'
# }
# `
#
#
#
# **Example of fire data model:**
#
# `
# {
#     '_id': ObjectId('5ce7568ba90b9bcb3df80122'),
# 	'latitude': -37.966,
# 	'longitude': 145.05100000000002,
# 	'datetime': datetime.datetime(2017, 12, 27, 4, 16, 51),
# 	'confidence': 78,
# 	'date': datetime.datetime(2017, 12, 27, 0, 0),
# 	'surface_temperature_celcius': 68
# }`

# %% [markdown]
# ## Task B
#
# ## Loading the historic data.
#
# As the task suggests, we are loading our historic data into a NoSQL database(MongoDB) for the company.

# %%
# read the csv file into respective variables.
climate = pd.read_csv("climate_historic.csv")
fire = pd.read_csv("hotspot_historic.csv")

# %%
print("Shape of Climate data:",climate.shape)
print("Shape of Fire data:",fire.shape)
# Out:
# Shape of Climate data: (366, 7)
# Shape of Fire data: (2668, 6)

# %%
# inspecting the climate data set.
climate.head(5)
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  31/12/2016                       19               56.8
# 1   948700   2/01/2017                       15               50.7
# 2   948700   3/01/2017                       16               53.6
# 3   948700   4/01/2017                       24               61.6
# 4   948700   5/01/2017                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation
# 0              7.9            11.1          0.00I
# 1              9.2            13.0          0.02G
# 2              8.1            15.0          0.00G
# 3              7.7            14.0          0.00I
# 4              7.0            13.0          0.00I

# %%
# inspecting the datatypes of the attributes to decide on 
climate.dtypes
# Out:
# station                      int64
# date                        object
# air_temperature_celcius      int64
# relative_humidity          float64
# windspeed_knots            float64
# max_wind_speed             float64
# precipitation               object
# dtype: object

# %%
# we noticed that the date attributes needs conversion to datetime object.

# we import dateutil.parser to convert the date attribute to a datetime object.

date = []
for i in climate.iterrows():
    date.append(dateutil.parser.parse(str(i[1].date)))

climate["date"] = date

# %%
# inspecting the fire data set.
fire.head(5)
# Out:
#    latitude  longitude             datetime  confidence        date  \
# 0   -37.966    145.051  2017-12-27T04:16:51          78  27/12/2017
# 1   -35.541    143.311  2017-12-27T00:02:15          82  27/12/2017
# 2   -35.554    143.307  2017-12-27T00:02:15          67  27/12/2017
# 3   -35.543    143.316  2017-12-27T00:02:14          86  27/12/2017
# 4   -37.708    145.100  2017-12-25T04:29:08          80  25/12/2017
#
#    surface_temperature_celcius
# 0                           68
# 1                           63
# 2                           53
# 3                           67
# 4                           54

# %%
# inspecting the datatypes of the attributes to decide on 
fire.dtypes
# Out:
# latitude                       float64
# longitude                      float64
# datetime                        object
# confidence                       int64
# date                            object
# surface_temperature_celcius      int64
# dtype: object

# %%
# we noticed that the date,datetime attributes needs conversion to datetime object.

# we import dateutil.parser to convert the date attribute to a datetime object.

date_time = []
date = []
for i in fire.iterrows():
    date_time.append(dateutil.parser.parse(i[1].datetime))
    date.append(dateutil.parser.parse(str(i[1].date)))
    
fire["datetime"] = date_time
fire["date"] = date

# %% [markdown]
# We will then convert all the fire and climate records into a dictionary format with key-value pairs according to records in a data.
# The code to perform the same is as follows:

# %%
# convert the records to key-value pair.
climate_dict = climate.to_dict(orient = "records")
fire_dict = fire.to_dict(orient = "records")

# %% [markdown]
# ### Insering the data into respective collections in database.
#
# We can use `insert_many()` function to insert many records of dictionary or json format into MongoDB. Code to perfome the same is as below:

# %%
# insert all the climate historic records to the collection.
climate_collection.insert_many(climate_dict)

# %%
# insert all the fire historic records to the collection.
fire_collection.insert_many(fire_dict)

# %%
# printing the first document in the climate collection.
for x in climate_collection.find():
    print(x)
    break
# Out:
# {'air_temperature_celcius': 19, 'relative_humidity': 56.8, 'precipitation ': ' 0.00I', '_id': ObjectId('5ce78e0a9343690e9b94dee5'), 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'station': 948700, 'date': datetime.datetime(2016, 12, 31, 0, 0)}

# %%
# printing the first document in the fire collection.
for y in fire_collection.find():
    print(y)
    break
# Out:
# {'confidence': 78, 'latitude': -37.966, 'datetime': datetime.datetime(2017, 12, 27, 4, 16, 51), '_id': ObjectId('5ce78e0d9343690e9b94e053'), 'longitude': 145.05100000000002, 'surface_temperature_celcius': 68, 'date': datetime.datetime(2017, 12, 27, 0, 0)}

# %% [markdown]
# ## Task B
#
# ## Querying MongoDB using PyMongo

# %% [markdown]
# #### A. Find climate data on ​10th December 2017.​

# %%
# finding climate data on 10th december

# query statement
myquery = {"date":datetime.strptime("10/12/2017", "%d/%m/%Y")}

# finding the record in the collection.
mydoc = climate_collection.find(myquery)

# printing the  output.
[x for x in mydoc]
# Out:
# [{'_id': ObjectId('5ce78fe39343690e9b94ebdb'),
#   'air_temperature_celcius': 15,
#   'date': datetime.datetime(2017, 12, 10, 0, 0),
#   'max_wind_speed': 14.0,
#   'precipitation ': ' 0.00G',
#   'relative_humidity': 44.5,
#   'station': 948702,
#   'windspeed_knots': 10.2}]

# %% [markdown]
# #### B. Find the latitude,​ ​longitude, surface temperature (​ °C)​, ​and ​confidence ​when the surface temperature (°C) was between ​65 °C​ and​ 100 °C.​

# %%
# query to find surface temp between 65 to 100
query = {"surface_temperature_celcius" : {"$gt" : 65,"$lt":100}}

# finding the record in the collection.
results = fire_collection.find(query,{"latitude": 1, "longitude":1,"confidence": 1,"surface_temperature_celcius":1,
                                    "_id":0}).sort([("surface_temperature_celcius",1)])

# printing the  output.
[x for x in results]
# Out:
# [{'confidence': 90,
#   'latitude': -37.624,
#   'longitude': 149.314,
#   'surface_temperature_celcius': 66},
#  {'confidence': 73,
#   'latitude': -37.444,
#   'longitude': 148.101,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.7032,
#   'longitude': 144.0992,
#   'surface_temperature_celcius': 66},
#  {'confidence': 85,
#   'latitude': -36.5023,
#   'longitude': 143.6038,
#   'surface_temperature_celcius': 66},
#  {'confidence': 89,
#   'latitude': -36.5116,
#   'longitude': 144.562,
#   'surface_temperature_celcius': 66},
#  {'confidence': 80,
#   'latitude': -36.1559,
#   'longitude': 141.8102,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -37.6267,
#   'longitude': 142.9993,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.6828,
#   'longitude': 144.784,
#   'surface_temperature_celcius': 66},
#  {'confidence': 89,
#   'latitude': -37.4843,
#   'longitude': 143.0592,
#   'surface_temperature_celcius': 66},
#  {'confidence': 84,
#   'latitude': -38.0423,
#   'longitude': 146.4048,
#   'surface_temperature_celcius': 66},
#  {'confidence': 89,
#   'latitude': -37.2609,
#   'longitude': 141.7999,
#   'surface_temperature_celcius': 66},
#  {'confidence': 78,
#   'latitude': -35.9326,
#   'longitude': 141.958,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -35.1949,
#   'longitude': 141.0622,
#   'surface_temperature_celcius': 66},
#  {'confidence': 89,
#   'latitude': -35.8071,
#   'longitude': 142.7318,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -37.8185,
#   'longitude': 142.5609,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.1462,
#   'longitude': 145.2096,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.8867,
#   'longitude': 142.1873,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.5399,
#   'longitude': 144.678,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.7165,
#   'longitude': 142.6155,
#   'surface_temperature_celcius': 66},
#  {'confidence': 76,
#   'latitude': -37.7966,
#   'longitude': 142.3196,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.6384,
#   'longitude': 142.4075,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -37.7835,
#   'longitude': 148.4138,
#   'surface_temperature_celcius': 66},
#  {'confidence': 85,
#   'latitude': -36.111,
#   'longitude': 145.124,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -36.1615,
#   'longitude': 141.8728,
#   'surface_temperature_celcius': 66},
#  {'confidence': 85,
#   'latitude': -35.4533,
#   'longitude': 143.2029,
#   'surface_temperature_celcius': 66},
#  {'confidence': 89,
#   'latitude': -37.7446,
#   'longitude': 143.4085,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -35.7657,
#   'longitude': 142.0906,
#   'surface_temperature_celcius': 66},
#  {'confidence': 90,
#   'latitude': -37.4523,
#   'longitude': 147.0175,
#   'surface_temperature_celcius': 66},
#  {'confidence': 86,
#   'latitude': -35.543,
#   'longitude': 143.316,
#   'surface_temperature_celcius': 67},
#  {'confidence': 92,
#   'latitude': -36.098,
#   'longitude': 143.74,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.4325,
#   'longitude': 144.3142,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -38.0372,
#   'longitude': 146.0616,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.2911,
#   'longitude': 141.1664,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.3435,
#   'longitude': 141.5513,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.094,
#   'longitude': 145.7646,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.1303,
#   'longitude': 146.3606,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.7101,
#   'longitude': 142.3865,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -37.7756,
#   'longitude': 143.1388,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -37.1349,
#   'longitude': 141.9491,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.429,
#   'longitude': 141.5759,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.8835,
#   'longitude': 142.2098,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.7903,
#   'longitude': 141.618,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.782,
#   'longitude': 141.8851,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.2857,
#   'longitude': 141.3467,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.5532,
#   'longitude': 142.5349,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -37.5788,
#   'longitude': 148.592,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -36.0387,
#   'longitude': 145.6787,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -35.4033,
#   'longitude': 143.267,
#   'surface_temperature_celcius': 67},
#  {'confidence': 79,
#   'latitude': -36.883,
#   'longitude': 142.1637,
#   'surface_temperature_celcius': 67},
#  {'confidence': 90,
#   'latitude': -34.357,
#   'longitude': 141.5361,
#   'surface_temperature_celcius': 67},
#  {'confidence': 78,
#   'latitude': -37.966,
#   'longitude': 145.05100000000002,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.247,
#   'longitude': 141.278,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.3774,
#   'longitude': 143.7079,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.7801,
#   'longitude': 142.7151,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.7746,
#   'longitude': 146.6642,
#   'surface_temperature_celcius': 68},
#  {'confidence': 90,
#   'latitude': -35.6871,
#   'longitude': 143.5235,
#   'surface_temperature_celcius': 68},
#  {'confidence': 84,
#   'latitude': -37.8323,
#   'longitude': 147.2232,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.4168,
#   'longitude': 141.6939,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -35.6138,
#   'longitude': 143.8666,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.5061,
#   'longitude': 144.5675,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.3635,
#   'longitude': 142.2809,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.7751,
#   'longitude': 145.1696,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.6397,
#   'longitude': 142.5968,
#   'surface_temperature_celcius': 68},
#  {'confidence': 77,
#   'latitude': -36.7101,
#   'longitude': 142.981,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.7171,
#   'longitude': 142.9505,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.0782,
#   'longitude': 145.3625,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.7651,
#   'longitude': 143.5801,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.3487,
#   'longitude': 145.5315,
#   'surface_temperature_celcius': 68},
#  {'confidence': 90,
#   'latitude': -36.5568,
#   'longitude': 144.0538,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.6171,
#   'longitude': 142.9426,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -36.4449,
#   'longitude': 140.9836,
#   'surface_temperature_celcius': 68},
#  {'confidence': 86,
#   'latitude': -37.5814,
#   'longitude': 148.5777,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -37.3803,
#   'longitude': 145.611,
#   'surface_temperature_celcius': 68},
#  {'confidence': 64,
#   'latitude': -36.6281,
#   'longitude': 142.4349,
#   'surface_temperature_celcius': 68},
#  {'confidence': 91,
#   'latitude': -38.0674,
#   'longitude': 142.965,
#   'surface_temperature_celcius': 68},
#  {'confidence': 90,
#   'latitude': -36.9939,
#   'longitude': 148.2244,
#   'surface_temperature_celcius': 68},
#  {'confidence': 80,
#   'latitude': -37.0055,
#   'longitude': 148.1582,
#   'surface_temperature_celcius': 68},
#  {'confidence': 89,
#   'latitude': -36.94,
#   'longitude': 143.281,
#   'surface_temperature_celcius': 69},
#  {'confidence': 64,
#   'latitude': -37.45,
#   'longitude': 148.126,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -37.8644,
#   'longitude': 143.4263,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.7685,
#   'longitude': 142.7134,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.5541,
#   'longitude': 144.1321,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -35.6819,
#   'longitude': 143.5275,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.3153,
#   'longitude': 140.9789,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.6564,
#   'longitude': 142.8615,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.3961,
#   'longitude': 140.9781,
#   'surface_temperature_celcius': 69},
#  {'confidence': 92,
#   'latitude': -36.7593,
#   'longitude': 142.895,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -37.6964,
#   'longitude': 142.8583,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.2637,
#   'longitude': 145.3649,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.6892,
#   'longitude': 145.2775,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.1748,
#   'longitude': 145.7582,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -37.4611,
#   'longitude': 144.9371,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -35.6453,
#   'longitude': 142.387,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -35.2363,
#   'longitude': 143.0004,
#   'surface_temperature_celcius': 69},
#  {'confidence': 92,
#   'latitude': -36.6334,
#   'longitude': 142.2244,
#   'surface_temperature_celcius': 69},
#  {'confidence': 91,
#   'latitude': -36.031,
#   'longitude': 145.6824,
#   'surface_temperature_celcius': 69},
#  {'confidence': 92,
#   'latitude': -37.95,
#   'longitude': 142.366,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.9396,
#   'longitude': 143.1462,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.3207,
#   'longitude': 140.9737,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.4463,
#   'longitude': 142.7829,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.803000000000004,
#   'longitude': 142.9261,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.882,
#   'longitude': 142.7108,
#   'surface_temperature_celcius': 70},
#  {'confidence': 87,
#   'latitude': -37.9091,
#   'longitude': 143.5105,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.9284,
#   'longitude': 143.108,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.6498,
#   'longitude': 142.5997,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.5828,
#   'longitude': 144.5775,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.2652,
#   'longitude': 145.3769,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.1924,
#   'longitude': 143.1716,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.9364,
#   'longitude': 143.4996,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.0749,
#   'longitude': 143.4058,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.4033,
#   'longitude': 143.6884,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.2063,
#   'longitude': 147.4713,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.2082,
#   'longitude': 147.4368,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -36.0157,
#   'longitude': 145.9414,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -38.0715,
#   'longitude': 142.9591,
#   'surface_temperature_celcius': 70},
#  {'confidence': 92,
#   'latitude': -37.6625,
#   'longitude': 144.287,
#   'surface_temperature_celcius': 70},
#  {'confidence': 100,
#   'latitude': -36.282,
#   'longitude': 146.157,
#   'surface_temperature_celcius': 71},
#  {'confidence': 100,
#   'latitude': -37.634,
#   'longitude': 149.237,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -38.2391,
#   'longitude': 142.82,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -37.7889,
#   'longitude': 143.1324,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.663000000000004,
#   'longitude': 142.8567,
#   'surface_temperature_celcius': 71},
#  {'confidence': 87,
#   'latitude': -38.0148,
#   'longitude': 146.5413,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.1346,
#   'longitude': 145.2196,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.0714,
#   'longitude': 145.7665,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.5586,
#   'longitude': 144.0423,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.1367,
#   'longitude': 145.2071,
#   'surface_temperature_celcius': 71},
#  {'confidence': 93,
#   'latitude': -36.6823,
#   'longitude': 142.5024,
#   'surface_temperature_celcius': 71},
#  {'confidence': 81,
#   'latitude': -36.0844,
#   'longitude': 141.4934,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -37.8161,
#   'longitude': 142.9286,
#   'surface_temperature_celcius': 71},
#  {'confidence': 66,
#   'latitude': -36.6299,
#   'longitude': 142.4234,
#   'surface_temperature_celcius': 71},
#  {'confidence': 92,
#   'latitude': -36.4557,
#   'longitude': 142.2434,
#   'surface_temperature_celcius': 71},
#  {'confidence': 84,
#   'latitude': -37.0193,
#   'longitude': 148.1459,
#   'surface_temperature_celcius': 71},
#  {'confidence': 61,
#   'latitude': -37.562,
#   'longitude': 148.05,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.2306,
#   'longitude': 143.6408,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.6657,
#   'longitude': 143.1675,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.5135,
#   'longitude': 142.7238,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.6942,
#   'longitude': 143.8021,
#   'surface_temperature_celcius': 72},
#  {'confidence': 70,
#   'latitude': -36.9303,
#   'longitude': 143.1034,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.9111,
#   'longitude': 142.692,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.769,
#   'longitude': 147.94,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.1964,
#   'longitude': 144.5217,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.5871,
#   'longitude': 144.4958,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.9157,
#   'longitude': 143.3544,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.8879,
#   'longitude': 141.6647,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.663000000000004,
#   'longitude': 141.3038,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.1941,
#   'longitude': 143.1604,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -36.5243,
#   'longitude': 142.0839,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.5888,
#   'longitude': 148.5949,
#   'surface_temperature_celcius': 72},
#  {'confidence': 86,
#   'latitude': -36.6986,
#   'longitude': 142.7259,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.3165,
#   'longitude': 147.4932,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.0769,
#   'longitude': 141.042,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.7465,
#   'longitude': 143.3806,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.3046,
#   'longitude': 143.5448,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -34.3539,
#   'longitude': 141.5547,
#   'surface_temperature_celcius': 72},
#  {'confidence': 93,
#   'latitude': -37.875,
#   'longitude': 142.51,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -38.056999999999995,
#   'longitude': 144.211,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -37.945,
#   'longitude': 144.35399999999998,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -37.4984,
#   'longitude': 142.9739,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -37.4671,
#   'longitude': 145.9962,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -37.6982,
#   'longitude': 143.0549,
#   'surface_temperature_celcius': 73},
#  {'confidence': 88,
#   'latitude': -38.0132,
#   'longitude': 146.5269,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.4046,
#   'longitude': 141.1534,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.388000000000005,
#   'longitude': 141.8309,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -37.7274,
#   'longitude': 142.9536,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -38.1693,
#   'longitude': 143.0466,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -38.1224,
#   'longitude': 143.7553,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -37.7236,
#   'longitude': 142.947,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.4899,
#   'longitude': 142.2805,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.91,
#   'longitude': 141.0704,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.8238,
#   'longitude': 143.5724,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -35.0616,
#   'longitude': 141.4417,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -36.3313,
#   'longitude': 141.0017,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.4489,
#   'longitude': 144.7685,
#   'surface_temperature_celcius': 73},
#  {'confidence': 93,
#   'latitude': -36.8099,
#   'longitude': 142.72799999999998,
#   'surface_temperature_celcius': 73},
#  {'confidence': 71,
#   'latitude': -37.522,
#   'longitude': 143.3874,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -37.2284,
#   'longitude': 147.9187,
#   'surface_temperature_celcius': 73},
#  {'confidence': 94,
#   'latitude': -38.049,
#   'longitude': 146.0513,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -36.2775,
#   'longitude': 146.1026,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -37.4357,
#   'longitude': 142.7813,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -37.7609,
#   'longitude': 143.1633,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -36.2121,
#   'longitude': 144.6885,
#   'surface_temperature_celcius': 74},
#  {'confidence': 88,
#   'latitude': -36.1546,
#   'longitude': 141.8146,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -36.3966,
#   'longitude': 141.406,
#   'surface_temperature_celcius': 74},
#  {'confidence': 67,
#   'latitude': -37.34,
#   'longitude': 149.3668,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -36.7806,
#   'longitude': 141.5597,
#   'surface_temperature_celcius': 74},
#  {'confidence': 94,
#   'latitude': -36.7152,
#   'longitude': 141.3853,
#   'surface_temperature_celcius': 74},
#  {'confidence': 95,
#   'latitude': -37.613,
#   'longitude': 149.305,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -36.0828,
#   'longitude': 145.873,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -36.4179,
#   'longitude': 144.2924,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -36.092,
#   'longitude': 141.7306,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -36.2933,
#   'longitude': 141.36,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -36.4816,
#   'longitude': 141.6635,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -35.0706,
#   'longitude': 141.4435,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -37.8906,
#   'longitude': 146.2035,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -37.5812,
#   'longitude': 142.7374,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -37.4028,
#   'longitude': 143.6932,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -37.7805,
#   'longitude': 143.5003,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -36.9959,
#   'longitude': 148.2118,
#   'surface_temperature_celcius': 75},
#  {'confidence': 94,
#   'latitude': -34.3555,
#   'longitude': 141.5495,
#   'surface_temperature_celcius': 75},
#  {'confidence': 95,
#   'latitude': -37.618,
#   'longitude': 149.281,
#   'surface_temperature_celcius': 76},
#  {'confidence': 86,
#   'latitude': -37.436,
#   'longitude': 148.088,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.0396,
#   'longitude': 141.7183,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -37.6854,
#   'longitude': 143.4543,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.0885,
#   'longitude': 145.0359,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -37.9509,
#   'longitude': 143.9599,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.7187,
#   'longitude': 143.805,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.6537,
#   'longitude': 143.8781,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -38.1987,
#   'longitude': 147.0666,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.3014,
#   'longitude': 143.203,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.6995,
#   'longitude': 142.97799999999998,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.8681,
#   'longitude': 143.5186,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.1418,
#   'longitude': 144.0261,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -37.224000000000004,
#   'longitude': 147.4347,
#   'surface_temperature_celcius': 76},
#  {'confidence': 90,
#   'latitude': -36.1104,
#   'longitude': 145.9829,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -37.3158,
#   'longitude': 147.4986,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -37.4323,
#   'longitude': 147.6583,
#   'surface_temperature_celcius': 76},
#  {'confidence': 90,
#   'latitude': -36.1122,
#   'longitude': 142.1491,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.4312,
#   'longitude': 141.2064,
#   'surface_temperature_celcius': 76},
#  {'confidence': 95,
#   'latitude': -36.8009,
#   'longitude': 142.7259,
#   'surface_temperature_celcius': 76},
#  {'confidence': 96,
#   'latitude': -37.475,
#   'longitude': 143.365,
#   'surface_temperature_celcius': 77},
#  {'confidence': 96,
#   'latitude': -38.126999999999995,
#   'longitude': 143.82,
#   'surface_temperature_celcius': 77},
#  {'confidence': 68,
#   'latitude': -37.452,
#   'longitude': 148.115,
#   'surface_temperature_celcius': 77},
#  {'confidence': 96,
#   'latitude': -36.3387,
#   'longitude': 141.7542,
#   'surface_temperature_celcius': 77},
#  {'confidence': 96,
#   'latitude': -36.3402,
#   'longitude': 141.7429,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.3254,
#   'longitude': 144.3638,
#   'surface_temperature_celcius': 77},
#  {'confidence': 96,
#   'latitude': -36.8094,
#   'longitude': 142.8885,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.6139,
#   'longitude': 143.501,
#   'surface_temperature_celcius': 77},
#  {'confidence': 83,
#   'latitude': -36.3195,
#   'longitude': 146.0601,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.7128,
#   'longitude': 142.3717,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.738,
#   'longitude': 142.1177,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.5199,
#   'longitude': 144.7311,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -36.3823,
#   'longitude': 141.3146,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -37.9152,
#   'longitude': 145.8808,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -37.8247,
#   'longitude': 143.6243,
#   'surface_temperature_celcius': 77},
#  {'confidence': 96,
#   'latitude': -37.7542,
#   'longitude': 142.9949,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -37.8072,
#   'longitude': 145.9738,
#   'surface_temperature_celcius': 77},
#  {'confidence': 95,
#   'latitude': -37.8774,
#   'longitude': 145.8213,
#   'surface_temperature_celcius': 77},
#  {'confidence': 62,
#   'latitude': -37.379,
#   'longitude': 148.132,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.1002,
#   'longitude': 142.3405,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.8359,
#   'longitude': 146.6448,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -37.253,
#   'longitude': 144.3681,
#   'surface_temperature_celcius': 78},
#  {'confidence': 90,
#   'latitude': -36.8616,
#   'longitude': 142.8025,
#   'surface_temperature_celcius': 78},
#  {'confidence': 84,
#   'latitude': -37.3656,
#   'longitude': 141.3903,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -38.0866,
#   'longitude': 143.9534,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.3438,
#   'longitude': 141.5832,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.3193,
#   'longitude': 145.9162,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -38.0933,
#   'longitude': 143.9824,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -37.8429,
#   'longitude': 147.2691,
#   'surface_temperature_celcius': 78},
#  {'confidence': 86,
#   'latitude': -37.6775,
#   'longitude': 148.5131,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.5847,
#   'longitude': 145.1968,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -37.7935,
#   'longitude': 143.1606,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.1898,
#   'longitude': 145.0922,
#   'surface_temperature_celcius': 78},
#  {'confidence': 84,
#   'latitude': -36.7531,
#   'longitude': 141.3253,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.9498,
#   'longitude': 142.2012,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -37.222,
#   'longitude': 147.4689,
#   'surface_temperature_celcius': 78},
#  {'confidence': 83,
#   'latitude': -37.803000000000004,
#   'longitude': 142.3151,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.1955,
#   'longitude': 145.914,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -36.6006,
#   'longitude': 141.9657,
#   'surface_temperature_celcius': 78},
#  {'confidence': 96,
#   'latitude': -37.3704,
#   'longitude': 145.8942,
#   'surface_temperature_celcius': 78},
#  {'confidence': 100,
#   'latitude': -37.400999999999996,
#   'longitude': 148.067,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.2842,
#   'longitude': 141.1741,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.0594,
#   'longitude': 141.5907,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.6787,
#   'longitude': 144.8042,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.5987,
#   'longitude': 144.4995,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.8298,
#   'longitude': 143.4483,
#   'surface_temperature_celcius': 79},
#  {'confidence': 84,
#   'latitude': -36.7432,
#   'longitude': 141.3296,
#   'surface_temperature_celcius': 79},
#  {'confidence': 97,
#   'latitude': -36.1067,
#   'longitude': 143.7948,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -36.1518,
#   'longitude': 144.0233,
#   'surface_temperature_celcius': 79},
#  {'confidence': 97,
#   'latitude': -36.1925,
#   'longitude': 145.93,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -37.6622,
#   'longitude': 142.1001,
#   'surface_temperature_celcius': 79},
#  {'confidence': 96,
#   'latitude': -34.3554,
#   'longitude': 141.5413,
#   'surface_temperature_celcius': 79},
#  {'confidence': 97,
#   'latitude': -37.61,
#   'longitude': 149.30700000000002,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.69,
#   'longitude': 143.605,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.369,
#   'longitude': 143.7132,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.6224,
#   'longitude': 143.5092,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.2206,
#   'longitude': 144.6856,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.7787,
#   'longitude': 141.4449,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.0669,
#   'longitude': 141.0556,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.8158,
#   'longitude': 142.6229,
#   'surface_temperature_celcius': 80},
#  {'confidence': 91,
#   'latitude': -36.4612,
#   'longitude': 144.7775,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.601,
#   'longitude': 144.6378,
#   'surface_temperature_celcius': 80},
#  {'confidence': 84,
#   'latitude': -37.7587,
#   'longitude': 142.8521,
#   'surface_temperature_celcius': 80},
#  {'confidence': 66,
#   'latitude': -37.3493,
#   'longitude': 149.3691,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.0924,
#   'longitude': 141.89700000000002,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.9452,
#   'longitude': 143.5834,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.0155,
#   'longitude': 148.1432,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -37.6572,
#   'longitude': 142.0703,
#   'surface_temperature_celcius': 80},
#  {'confidence': 97,
#   'latitude': -36.4169,
#   'longitude': 144.2994,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -36.4211,
#   'longitude': 141.6875,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -37.4885,
#   'longitude': 142.0658,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -36.6527,
#   'longitude': 142.7392,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -36.4538,
#   'longitude': 144.763,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -37.7617,
#   'longitude': 143.08100000000002,
#   'surface_temperature_celcius': 81},
#  {'confidence': 92,
#   'latitude': -36.5989,
#   'longitude': 141.9771,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -37.9247,
#   'longitude': 142.8999,
#   'surface_temperature_celcius': 81},
#  {'confidence': 97,
#   'latitude': -35.0805,
#   'longitude': 142.4642,
#   'surface_temperature_celcius': 81},
#  {'confidence': 58,
#   'latitude': -37.379,
#   'longitude': 148.126,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -37.9085,
#   'longitude': 141.1038,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -38.2375,
#   'longitude': 142.8363,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -36.0652,
#   'longitude': 146.0764,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -37.758,
#   'longitude': 143.179,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -38.0509,
#   'longitude': 143.9423,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -36.5921,
#   'longitude': 144.4905,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -36.9329,
#   'longitude': 143.7796,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -36.2948,
#   'longitude': 141.3486,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -37.618,
#   'longitude': 143.0013,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -36.095,
#   'longitude': 141.7699,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -37.7509,
#   'longitude': 143.4023,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -34.3526,
#   'longitude': 141.6458,
#   'surface_temperature_celcius': 82},
#  {'confidence': 98,
#   'latitude': -37.605,
#   'longitude': 149.30200000000002,
#   'surface_temperature_celcius': 83},
#  {'confidence': 98,
#   'latitude': -38.2853,
#   'longitude': 145.9519,
#   'surface_temperature_celcius': 83},
#  {'confidence': 98,
#   'latitude': -35.2381,
#   'longitude': 142.994,
#   'surface_temperature_celcius': 83},
#  {'confidence': 93,
#   'latitude': -37.6439,
#   'longitude': 142.91299999999998,
#   'surface_temperature_celcius': 83},
#  {'confidence': 98,
#   'latitude': -37.4261,
#   'longitude': 147.0323,
#   'surface_temperature_celcius': 83},
#  {'confidence': 99,
#   'latitude': -37.609,
#   'longitude': 149.32,
#   'surface_temperature_celcius': 84},
#  {'confidence': 100,
#   'latitude': -37.399,
#   'longitude': 148.08100000000002,
#   'surface_temperature_celcius': 84},
#  {'confidence': 99,
#   'latitude': -38.0881,
#   'longitude': 143.9391,
#   'surface_temperature_celcius': 84},
#  {'confidence': 99,
#   'latitude': -36.4286,
#   'longitude': 141.1567,
#   'surface_temperature_celcius': 84},
#  {'confidence': 98,
#   'latitude': -36.8742,
#   'longitude': 142.7177,
#   'surface_temperature_celcius': 84},
#  {'confidence': 99,
#   'latitude': -36.5438,
#   'longitude': 144.7548,
#   'surface_temperature_celcius': 84},
#  {'confidence': 98,
#   'latitude': -36.1345,
#   'longitude': 146.351,
#   'surface_temperature_celcius': 84},
#  {'confidence': 98,
#   'latitude': -36.5262,
#   'longitude': 144.5737,
#   'surface_temperature_celcius': 84},
#  {'confidence': 99,
#   'latitude': -36.7943,
#   'longitude': 143.9571,
#   'surface_temperature_celcius': 84},
#  {'confidence': 99,
#   'latitude': -37.293,
#   'longitude': 141.245,
#   'surface_temperature_celcius': 85},
#  {'confidence': 94,
#   'latitude': -36.2693,
#   'longitude': 143.1768,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -37.5867,
#   'longitude': 143.6256,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -36.1586,
#   'longitude': 145.6666,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -35.8276,
#   'longitude': 143.7549,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -36.0691,
#   'longitude': 145.7797,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -37.8885,
#   'longitude': 143.9157,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -36.7287,
#   'longitude': 142.6017,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -37.777,
#   'longitude': 148.4128,
#   'surface_temperature_celcius': 85},
#  {'confidence': 99,
#   'latitude': -37.6,
#   'longitude': 149.325,
#   'surface_temperature_celcius': 86},
#  {'confidence': 99,
#   'latitude': -36.2882,
#   'longitude': 141.1821,
#   'surface_temperature_celcius': 86},
#  {'confidence': 99,
#   'latitude': -36.7153,
#   'longitude': 143.8226,
#   'surface_temperature_celcius': 86},
#  {'confidence': 99,
#   'latitude': -37.5115,
#   'longitude': 143.14,
#   'surface_temperature_celcius': 86},
#  {'confidence': 100,
#   'latitude': -35.8768,
#   'longitude': 145.4627,
#   'surface_temperature_celcius': 86},
#  {'confidence': 94,
#   'latitude': -36.6349,
#   'longitude': 142.2125,
#   'surface_temperature_celcius': 86},
#  {'confidence': 99,
#   'latitude': -37.7236,
#   'longitude': 143.3995,
#   'surface_temperature_celcius': 86},
#  {'confidence': 99,
#   'latitude': -34.351,
#   'longitude': 141.6567,
#   'surface_temperature_celcius': 86},
#  {'confidence': 100,
#   'latitude': -37.606,
#   'longitude': 149.312,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -37.294000000000004,
#   'longitude': 141.232,
#   'surface_temperature_celcius': 87},
#  {'confidence': 94,
#   'latitude': -37.4796,
#   'longitude': 141.9403,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -36.345,
#   'longitude': 143.4256,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -36.664,
#   'longitude': 142.8802,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -37.8412,
#   'longitude': 147.2536,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -37.9594,
#   'longitude': 143.5638,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -36.7957,
#   'longitude': 143.9652,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -36.0837,
#   'longitude': 144.2448,
#   'surface_temperature_celcius': 87},
#  {'confidence': 100,
#   'latitude': -37.406,
#   'longitude': 148.123,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -36.3756,
#   'longitude': 143.7243,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -36.7309,
#   'longitude': 142.3633,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -37.9071,
#   'longitude': 143.53799999999998,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -36.3999,
#   'longitude': 144.737,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -37.3847,
#   'longitude': 142.8935,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -37.8429,
#   'longitude': 143.8366,
#   'surface_temperature_celcius': 88},
#  {'confidence': 87,
#   'latitude': -37.6387,
#   'longitude': 142.9032,
#   'surface_temperature_celcius': 88},
#  {'confidence': 100,
#   'latitude': -36.3799,
#   'longitude': 143.7149,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -38.5123,
#   'longitude': 146.4007,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -36.7742,
#   'longitude': 145.1991,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.7002,
#   'longitude': 142.9562,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.0761,
#   'longitude': 141.0574,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.4591,
#   'longitude': 144.9492,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.2168,
#   'longitude': 147.4748,
#   'surface_temperature_celcius': 89},
#  {'confidence': 94,
#   'latitude': -38.0052,
#   'longitude': 142.6179,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.383,
#   'longitude': 145.9089,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -38.0693,
#   'longitude': 142.9722,
#   'surface_temperature_celcius': 89},
#  {'confidence': 100,
#   'latitude': -37.461999999999996,
#   'longitude': 148.089,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -37.9047,
#   'longitude': 141.0945,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -38.0361,
#   'longitude': 146.0567,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -36.1532,
#   'longitude': 143.5527,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -36.0682,
#   'longitude': 146.0602,
#   'surface_temperature_celcius': 90},
#  {'confidence': 87,
#   'latitude': -36.3332,
#   'longitude': 145.8594,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -36.6615,
#   'longitude': 144.6014,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -37.0899,
#   'longitude': 141.0238,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -37.1999,
#   'longitude': 143.8231,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -36.3972,
#   'longitude': 141.6041,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -37.2988,
#   'longitude': 143.5487,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -37.5012,
#   'longitude': 142.5853,
#   'surface_temperature_celcius': 90},
#  {'confidence': 100,
#   'latitude': -36.3459,
#   'longitude': 141.5586,
#   'surface_temperature_celcius': 91},
#  {'confidence': 100,
#   'latitude': -38.0795,
#   'longitude': 143.2449,
#   'surface_temperature_celcius': 91},
#  {'confidence': 100,
#   'latitude': -37.3949,
#   'longitude': 147.0175,
#   'surface_temperature_celcius': 91},
#  {'confidence': 100,
#   'latitude': -36.4125,
#   'longitude': 143.1189,
#   'surface_temperature_celcius': 92},
#  {'confidence': 100,
#   'latitude': -35.1857,
#   'longitude': 141.0604,
#   'surface_temperature_celcius': 92},
#  {'confidence': 100,
#   'latitude': -36.4409,
#   'longitude': 141.6948,
#   'surface_temperature_celcius': 92},
#  {'confidence': 100,
#   'latitude': -35.8182,
#   'longitude': 143.8739,
#   'surface_temperature_celcius': 92},
#  {'confidence': 100,
#   'latitude': -37.4343,
#   'longitude': 147.6327,
#   'surface_temperature_celcius': 92},
#  {'confidence': 87,
#   'latitude': -36.0973,
#   'longitude': 143.4279,
#   'surface_temperature_celcius': 92},
#  {'confidence': 100,
#   'latitude': -37.477,
#   'longitude': 143.352,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -38.4349,
#   'longitude': 146.3122,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.0077,
#   'longitude': 141.7747,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.8791,
#   'longitude': 142.7261,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -37.5043,
#   'longitude': 146.3299,
#   'surface_temperature_celcius': 93},
#  {'confidence': 94,
#   'latitude': -38.0792,
#   'longitude': 143.7361,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.8283,
#   'longitude': 143.4605,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.1771,
#   'longitude': 145.7451,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.7089,
#   'longitude': 143.3518,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -35.6469,
#   'longitude': 142.376,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -37.9174,
#   'longitude': 145.8678,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -37.297,
#   'longitude': 143.5753,
#   'surface_temperature_celcius': 93},
#  {'confidence': 100,
#   'latitude': -36.3433,
#   'longitude': 143.4369,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -36.0576,
#   'longitude': 141.6122,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -38.1917,
#   'longitude': 147.0745,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -36.5854,
#   'longitude': 143.0462,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -37.5701,
#   'longitude': 142.6497,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -35.2378,
#   'longitude': 142.9864,
#   'surface_temperature_celcius': 94},
#  {'confidence': 100,
#   'latitude': -36.1506,
#   'longitude': 143.5671,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -36.4035,
#   'longitude': 140.9935,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -37.5027,
#   'longitude': 146.347,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -38.027,
#   'longitude': 142.3844,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -35.6374,
#   'longitude': 142.3787,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -35.805,
#   'longitude': 142.1326,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -36.9034,
#   'longitude': 141.0013,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -37.3735,
#   'longitude': 145.8384,
#   'surface_temperature_celcius': 95},
#  {'confidence': 100,
#   'latitude': -36.5454,
#   'longitude': 144.7402,
#   'surface_temperature_celcius': 96},
#  {'confidence': 100,
#   'latitude': -37.4352,
#   'longitude': 143.1444,
#   'surface_temperature_celcius': 96},
#  {'confidence': 100,
#   'latitude': -36.91,
#   'longitude': 141.2705,
#   'surface_temperature_celcius': 96},
#  {'confidence': 100,
#   'latitude': -37.9246,
#   'longitude': 146.2464,
#   'surface_temperature_celcius': 96},
#  {'confidence': 94,
#   'latitude': -35.811,
#   'longitude': 142.1403,
#   'surface_temperature_celcius': 96},
#  {'confidence': 87,
#   'latitude': -37.3735,
#   'longitude': 145.886,
#   'surface_temperature_celcius': 96},
#  {'confidence': 100,
#   'latitude': -36.4142,
#   'longitude': 143.1077,
#   'surface_temperature_celcius': 97},
#  {'confidence': 100,
#   'latitude': -36.4518,
#   'longitude': 144.7752,
#   'surface_temperature_celcius': 97},
#  {'confidence': 100,
#   'latitude': -36.9918,
#   'longitude': 141.8667,
#   'surface_temperature_celcius': 97},
#  {'confidence': 87,
#   'latitude': -37.7974,
#   'longitude': 145.9535,
#   'surface_temperature_celcius': 97},
#  {'confidence': 100,
#   'latitude': -36.0816,
#   'longitude': 145.859,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -36.7708,
#   'longitude': 145.1908,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -37.3902,
#   'longitude': 148.2955,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -37.5728,
#   'longitude': 142.6348,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -37.5949,
#   'longitude': 142.6857,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -37.8249,
#   'longitude': 143.6174,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -36.1819,
#   'longitude': 145.9269,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -37.3025,
#   'longitude': 143.5714,
#   'surface_temperature_celcius': 98},
#  {'confidence': 85,
#   'latitude': -37.4128,
#   'longitude': 147.0242,
#   'surface_temperature_celcius': 98},
#  {'confidence': 100,
#   'latitude': -36.5839,
#   'longitude': 143.0588,
#   'surface_temperature_celcius': 99},
#  {'confidence': 75,
#   'latitude': -36.7499,
#   'longitude': 141.3006,
#   'surface_temperature_celcius': 99},
#  {'confidence': 100,
#   'latitude': -38.0254,
#   'longitude': 142.3959,
#   'surface_temperature_celcius': 99},
#  {'confidence': 100,
#   'latitude': -37.782,
#   'longitude': 148.3844,
#   'surface_temperature_celcius': 99},
#  {'confidence': 100,
#   'latitude': -37.8881,
#   'longitude': 145.8229,
#   'surface_temperature_celcius': 99},
#  {'confidence': 100,
#   'latitude': -37.4229,
#   'longitude': 147.02700000000002,
#   'surface_temperature_celcius': 99}]

# %% [markdown]
# #### C. Find ​date,​ ​surface temperature (°C), air temperature (°C), relative humidity and max wind speed on​ 15th and 16th of December 2017.

# %%
# perform aggrigation and find the records for the given condition.

# NOTE: We have decided not to unwind the result, so we dont make the output redundant.
result = mydb.climate.aggregate([{
    "$lookup":
    {
        "from": "fire",
        "localField": "date",
        "foreignField": "date",
        "as":"fire",
    }},
    {
    "$match" : {"$or":[{"date": datetime.strptime("15/12/2017", "%d/%m/%Y")},{"date":datetime.strptime("16/12/2017", "%d/%m/%Y")}]}

    },
    {
    "$project" : {"_id":0,"date":1,"air_temperature_celcius":1,"relative_humidity":1,"max_wind_speed":1,"fire":{"surface_temperature_celcius":1}}  
    }
    ])

# %%
# printing the  output.
[x for x in result]
# Out:
# [{'air_temperature_celcius': 18,
#   'date': datetime.datetime(2017, 12, 15, 0, 0),
#   'fire': [{'surface_temperature_celcius': 42},
#    {'surface_temperature_celcius': 36},
#    {'surface_temperature_celcius': 38},
#    {'surface_temperature_celcius': 40}],
#   'max_wind_speed': 14.0,
#   'relative_humidity': 52.0},
#  {'air_temperature_celcius': 18,
#   'date': datetime.datetime(2017, 12, 16, 0, 0),
#   'fire': [{'surface_temperature_celcius': 43},
#    {'surface_temperature_celcius': 33},
#    {'surface_temperature_celcius': 54},
#    {'surface_temperature_celcius': 73},
#    {'surface_temperature_celcius': 55},
#    {'surface_temperature_celcius': 75},
#    {'surface_temperature_celcius': 55},
#    {'surface_temperature_celcius': 66},
#    {'surface_temperature_celcius': 56},
#    {'surface_temperature_celcius': 60},
#    {'surface_temperature_celcius': 73},
#    {'surface_temperature_celcius': 48},
#    {'surface_temperature_celcius': 55},
#    {'surface_temperature_celcius': 64},
#    {'surface_temperature_celcius': 57}],
#   'max_wind_speed': 13.0,
#   'relative_humidity': 53.7}]

# %% [markdown]
# #### D. Find ​datetime, air temperature (°C), surface temperature (°C) and ​confidence when the ​confidence i​ s between 80 and 100.

# %%
# perform aggrigation and find the records for confidence between 80 and 100.

result = mydb.fire.aggregate([{
    "$lookup":
    {
        "from": "climate",
        "localField": "date",
        "foreignField": "date",
        "as":"climate",
    }},
    {
    "$project" : {"_id":0,"datetime": 1,
                "surface_temperature_celcius":1,"confidence":1,
                "climate":{"air_temperature_celcius":1}}  
    },
    {
    "$match" : {"confidence":{"$gt": 80, "$lt": 100}}
    }
    ])

# %%
# printing the  output.
[x for x in result]
# Out:
# [{'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 12, 27, 0, 2, 15),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 12, 27, 0, 2, 14),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 12, 16, 15, 38, 39),
#   'surface_temperature_celcius': 43},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 12, 16, 4, 35, 13),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 12, 16, 4, 34, 58),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 12, 16, 4, 34, 58),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 12, 16, 4, 34, 57),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 12, 16, 0, 21, 12),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 12, 16, 0, 21, 11),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 12, 16, 0, 20, 53),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 12, 15, 13, 17, 17),
#   'surface_temperature_celcius': 42},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 12, 14, 4, 47, 25),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 12, 13, 4, 4, 19),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 12, 9, 0, 14, 34),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 12, 9, 0, 14, 34),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 12, 9, 0, 14, 33),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 12, 9, 0, 14, 33),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#   'surface_temperature_celcius': 38},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15),
#   'surface_temperature_celcius': 42},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 11, 30, 4, 35),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#   'surface_temperature_celcius': 83},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57),
#   'surface_temperature_celcius': 86},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 11, 29, 3, 52, 10),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 11, 29, 3, 52, 10),
#   'surface_temperature_celcius': 84},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 11, 23, 4, 28, 59),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 11, 23, 4, 28, 59),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 11, 22, 3, 46),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 11, 22, 3, 46),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 11, 21, 0, 27, 21),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 28}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 11, 14, 4, 35, 4),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 11, 13, 3, 52, 15),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 11, 13, 3, 52, 14),
#   'surface_temperature_celcius': 53},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 11, 12, 0, 33, 15),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 11, 11, 4, 4, 25),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 11, 9, 4, 16, 48),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 11, 9, 4, 16, 48),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 11, 9, 4, 16, 44),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 11, 9, 4, 16, 44),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 11, 5, 4, 41, 34),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 11, 5, 4, 41, 19),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 11, 5, 4, 41, 19),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 10, 28, 3, 52, 17),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 22}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 10, 27, 4, 47, 31),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 10, 21, 1, 9, 55),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 10, 21, 1, 9, 54),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 10, 20, 4, 41, 19),
#   'surface_temperature_celcius': 50},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 26}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 22}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 10, 17, 13, 36, 12),
#   'surface_temperature_celcius': 43},
#  {'climate': [{'air_temperature_celcius': 22}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 10, 17, 4, 10, 45),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 22}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 10, 17, 4, 10, 32),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 10, 15, 4, 23, 1),
#   'surface_temperature_celcius': 85},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 10, 10, 4, 4, 19),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 10, 7, 12, 59, 33),
#   'surface_temperature_celcius': 42},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 10, 4, 4, 41),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 10, 4, 4, 41),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 10, 3, 13, 23, 43),
#   'surface_temperature_celcius': 42},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#   'surface_temperature_celcius': 48},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#   'surface_temperature_celcius': 49},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 14),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 10, 3, 3, 58, 14),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 10, 2, 4, 53, 10),
#   'surface_temperature_celcius': 50},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 10, 2, 4, 53, 9),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 10, 1, 4, 10, 28),
#   'surface_temperature_celcius': 52},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 10, 1, 4, 10, 28),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 9, 29, 4, 22, 31),
#   'surface_temperature_celcius': 49},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 9, 27, 4, 35, 36),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 9, 27, 4, 35, 36),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 9, 24, 15, 7, 47),
#   'surface_temperature_celcius': 41},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 9, 24, 15, 7, 47),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 9, 24, 15, 7, 45),
#   'surface_temperature_celcius': 43},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 9, 24, 13, 30, 9),
#   'surface_temperature_celcius': 38},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 9, 24, 13, 30, 7),
#   'surface_temperature_celcius': 50},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 9, 24, 4, 4, 18),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 9, 24, 4, 4, 4),
#   'surface_temperature_celcius': 52},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 9, 23, 23, 50, 44),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 9, 23, 4, 59, 13),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 9, 23, 4, 59, 11),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 9, 20, 4, 29, 3),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 9, 20, 4, 28, 45),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 9, 10, 3, 53),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 9, 10, 3, 50, 30),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 9, 10, 3, 50, 10),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 8, 13, 5, 8),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 8, 13, 5, 2, 30),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 5}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 8, 2, 3, 45, 40),
#   'surface_temperature_celcius': 87},
#  {'climate': [{'air_temperature_celcius': 7}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 8, 1, 0, 20, 30),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 7}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 7, 31, 13, 21),
#   'surface_temperature_celcius': 43},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 7, 6, 4, 8),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 7, 6, 4, 2),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 6}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18),
#   'surface_temperature_celcius': 52},
#  {'climate': [{'air_temperature_celcius': 6}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18),
#   'surface_temperature_celcius': 52},
#  {'climate': [{'air_temperature_celcius': 6}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 7, 2, 4, 29),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 6}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 7, 2, 4, 29),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 5}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19),
#   'surface_temperature_celcius': 48},
#  {'climate': [{'air_temperature_celcius': 5}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19),
#   'surface_temperature_celcius': 48},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 6, 20, 4, 2),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 6, 14, 4, 43),
#   'surface_temperature_celcius': 85},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 6, 9, 4, 23, 20),
#   'surface_temperature_celcius': 52},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 6, 9, 4, 23, 16),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 35, 50),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 33, 50),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 8}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 6, 4, 4, 8, 20),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 6, 4, 4, 8, 10),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 6, 4, 4, 2, 10),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 6, 4, 4, 2, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 11}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 6, 1, 5, 9, 20),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 13}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 26, 4, 8, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 23, 0, 58),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 23, 0, 54, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 22, 4, 32, 20),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 22, 0, 15),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 17}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 22, 0, 13),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 34, 30),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 34, 30),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 33),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 33),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 32, 50),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 31, 20),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 31, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 30),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 28),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 27, 50),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 43, 30),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 39, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 39, 30),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 39),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 12, 3, 57, 40),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 5, 12, 3, 56, 10),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 12, 3, 56, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 57, 20),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 57, 20),
#   'surface_temperature_celcius': 79},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 54),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 51),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 86},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 9}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40),
#   'surface_temperature_celcius': 81},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 16, 30),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 16, 10),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 14, 20),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 12, 50),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 12, 50),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 11, 30),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#   'surface_temperature_celcius': 83},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 84},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10),
#   'surface_temperature_celcius': 85},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 9, 12, 56, 40),
#   'surface_temperature_celcius': 39},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 9, 5, 2, 50),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 26, 50),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 24),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 20, 20),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 20, 10),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 20, 10),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 5, 8, 4, 20, 10),
#   'surface_temperature_celcius': 81},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 6, 4, 39),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 6, 4, 33),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 6, 4, 32, 50),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 5, 6, 4, 32, 30),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 6, 4, 32, 20),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 6, 0, 16, 40),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 12}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 6, 0, 13, 50),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 59, 10),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 57),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 53, 20),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 53, 10),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 53, 10),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 51, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 53, 10),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 48, 50),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 48, 20),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 48, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 46, 50),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 46, 30),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 46, 20),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 46, 20),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 46, 20),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45, 40),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45, 40),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45, 30),
#   'surface_temperature_celcius': 84},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45, 30),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45, 10),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 45),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 84},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 69},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 86},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 5, 4, 0, 28, 30),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 5, 4, 0, 25, 30),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 10}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 5, 4, 0, 25),
#   'surface_temperature_celcius': 78},
# ...
#   'datetime': datetime.datetime(2017, 4, 3, 13, 15, 10),
#   'surface_temperature_celcius': 45},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 59, 10),
#   'surface_temperature_celcius': 96},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 57, 50),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 56, 20),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 55, 10),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 55, 10),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 54),
#   'surface_temperature_celcius': 78},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 53, 30),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 52, 30),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 52, 10),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 52, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 51, 30),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 51, 30),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 51, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 51),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 51),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 50),
#   'surface_temperature_celcius': 97},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 50),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 86},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 15}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 4, 3, 1, 7, 20),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 3, 31, 5, 7, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 31, 5, 1, 20),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 3, 31, 4, 58, 30),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 3, 31, 4, 57, 10),
#   'surface_temperature_celcius': 61},
#  {'climate': [{'air_temperature_celcius': 14}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 31, 0, 36, 30),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 38),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 33, 40),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 33, 30),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 33, 30),
#   'surface_temperature_celcius': 76},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 32, 20),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 30, 50),
#   'surface_temperature_celcius': 56},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#   'surface_temperature_celcius': 82},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 27, 40),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 27),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 99,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 27),
#   'surface_temperature_celcius': 86},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 81},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 63},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 81},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 83,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 57},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 43, 20),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 50),
#   'surface_temperature_celcius': 54},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 91,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 82,
#   'datetime': datetime.datetime(2017, 3, 25, 3, 59, 50),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 25, 3, 58, 10),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 3, 25, 3, 58, 10),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10),
#   'surface_temperature_celcius': 77},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 39, 50),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 39, 20),
#   'surface_temperature_celcius': 79},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 36),
#   'surface_temperature_celcius': 66},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 98,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 33),
#   'surface_temperature_celcius': 83},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 32, 50),
#   'surface_temperature_celcius': 58},
#  {'climate': [{'air_temperature_celcius': 24}],
#   'confidence': 92,
#   'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40),
#   'surface_temperature_celcius': 70},
#  {'climate': [{'air_temperature_celcius': 21}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 18, 3, 50, 40),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 3, 17, 4, 48, 20),
#   'surface_temperature_celcius': 74},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 3, 17, 4, 45, 10),
#   'surface_temperature_celcius': 59},
#  {'climate': [{'air_temperature_celcius': 18}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 3, 17, 4, 45),
#   'surface_temperature_celcius': 60},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 24, 40),
#   'surface_temperature_celcius': 67},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 93,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 22, 20),
#   'surface_temperature_celcius': 72},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 90,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 20, 50),
#   'surface_temperature_celcius': 68},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 95,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 16, 30),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 89,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 16, 20),
#   'surface_temperature_celcius': 65},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 14, 40),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 96,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 14, 30),
#   'surface_temperature_celcius': 79},
#  {'climate': [{'air_temperature_celcius': 25}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 3, 14, 4, 14, 30),
#   'surface_temperature_celcius': 75},
#  {'climate': [{'air_temperature_celcius': 21}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 3, 12, 4, 33, 50),
#   'surface_temperature_celcius': 105},
#  {'climate': [{'air_temperature_celcius': 21}],
#   'confidence': 84,
#   'datetime': datetime.datetime(2017, 3, 12, 4, 29, 50),
#   'surface_temperature_celcius': 71},
#  {'climate': [{'air_temperature_celcius': 21}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 12, 4, 27, 20),
#   'surface_temperature_celcius': 98},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 94,
#   'datetime': datetime.datetime(2017, 3, 10, 4, 45, 30),
#   'surface_temperature_celcius': 73},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 97,
#   'datetime': datetime.datetime(2017, 3, 10, 4, 45, 30),
#   'surface_temperature_celcius': 80},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 81,
#   'datetime': datetime.datetime(2017, 3, 10, 4, 43, 50),
#   'surface_temperature_celcius': 55},
#  {'climate': [{'air_temperature_celcius': 23}],
#   'confidence': 86,
#   'datetime': datetime.datetime(2017, 3, 9, 13, 23, 40),
#   'surface_temperature_celcius': 41},
#  {'climate': [{'air_temperature_celcius': 19}],
#   'confidence': 88,
#   'datetime': datetime.datetime(2017, 3, 7, 4, 16, 10),
#   'surface_temperature_celcius': 64},
#  {'climate': [{'air_temperature_celcius': 20}],
#   'confidence': 87,
#   'datetime': datetime.datetime(2017, 3, 6, 5, 6, 30),
#   'surface_temperature_celcius': 62},
#  {'climate': [{'air_temperature_celcius': 20}],
#   'confidence': 85,
#   'datetime': datetime.datetime(2017, 3, 6, 5, 6, 20),
#   'surface_temperature_celcius': 59}]

# %% [markdown]
# #### E. Find the top 10 records with the highest ​surface temperature​ ​(°C).

# %%
#  query to aggregate top 10 records w.r.t surface temperature
results = fire_collection.aggregate([{"$sort": {"surface_temperature_celcius":-1}},{"$limit": 10}])

# print the output
[x for x in results]
# Out:
# [{'_id': ObjectId('5ce78fe69343690e9b94f0d0'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 18, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 18, 4, 52),
#   'latitude': -38.1665,
#   'longitude': 143.062,
#   'surface_temperature_celcius': 124},
#  {'_id': ObjectId('5ce78fe69343690e9b94f57a'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 4, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50),
#   'latitude': -36.343,
#   'longitude': 142.1986,
#   'surface_temperature_celcius': 123},
#  {'_id': ObjectId('5ce78fe69343690e9b94f042'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 1, 5, 0, 0),
#   'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20),
#   'latitude': -36.9318,
#   'longitude': 143.0907,
#   'surface_temperature_celcius': 122},
#  {'_id': ObjectId('5ce78fe69343690e9b94f669'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 3, 18, 0, 0),
#   'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50),
#   'latitude': -37.016999999999996,
#   'longitude': 148.1297,
#   'surface_temperature_celcius': 121},
#  {'_id': ObjectId('5ce78fe69343690e9b94ee54'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 5, 13, 0, 0),
#   'datetime': datetime.datetime(2017, 5, 13, 4, 40, 20),
#   'latitude': -34.9938,
#   'longitude': 141.876,
#   'surface_temperature_celcius': 120},
#  {'_id': ObjectId('5ce78fe69343690e9b94f541'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 4, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 4, 4, 40),
#   'latitude': -36.1057,
#   'longitude': 141.7608,
#   'surface_temperature_celcius': 120},
#  {'_id': ObjectId('5ce78fe69343690e9b94f581'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 4, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40),
#   'latitude': -36.3521,
#   'longitude': 142.2008,
#   'surface_temperature_celcius': 120},
#  {'_id': ObjectId('5ce78fe69343690e9b94f2ec'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 13, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10),
#   'latitude': -37.0745,
#   'longitude': 141.0692,
#   'surface_temperature_celcius': 120},
#  {'_id': ObjectId('5ce78fe69343690e9b94f169'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 18, 0, 0),
#   'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50),
#   'latitude': -37.8326,
#   'longitude': 143.4999,
#   'surface_temperature_celcius': 120},
#  {'_id': ObjectId('5ce78fe69343690e9b94ef98'),
#   'confidence': 100,
#   'date': datetime.datetime(2017, 4, 5, 0, 0),
#   'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50),
#   'latitude': -36.4057,
#   'longitude': 140.9806,
#   'surface_temperature_celcius': 119}]

# %% [markdown]
# #### F. Find the number of fire in each day. You are required to only display ​the total number of fire​ and ​the date​ in the output.

# %%
# We can determine number of fire in each day
result = fire_collection.aggregate([
    {"$group" : {"_id":"$date", "Number of fires":{"$sum":1}}},
    { "$project" : { "_id" : 0, "date": "$_id", "Number of fires":1 } } 
])

# print the output
[x for x in result]
# Out:
# [{'Number of fires': 2, 'date': datetime.datetime(2017, 6, 3, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 8, 3, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 9, 3, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 3, 13, 0, 0)},
#  {'Number of fires': 7, 'date': datetime.datetime(2017, 3, 15, 0, 0)},
#  {'Number of fires': 6, 'date': datetime.datetime(2017, 3, 17, 0, 0)},
#  {'Number of fires': 21, 'date': datetime.datetime(2017, 3, 19, 0, 0)},
#  {'Number of fires': 54, 'date': datetime.datetime(2017, 3, 28, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 2, 4, 0, 0)},
#  {'Number of fires': 49, 'date': datetime.datetime(2017, 5, 4, 0, 0)},
#  {'Number of fires': 20, 'date': datetime.datetime(2017, 8, 4, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 3, 24, 0, 0)},
#  {'Number of fires': 24, 'date': datetime.datetime(2017, 11, 4, 0, 0)},
#  {'Number of fires': 69, 'date': datetime.datetime(2017, 12, 4, 0, 0)},
#  {'Number of fires': 357, 'date': datetime.datetime(2017, 4, 13, 0, 0)},
#  {'Number of fires': 18, 'date': datetime.datetime(2017, 4, 14, 0, 0)},
#  {'Number of fires': 69, 'date': datetime.datetime(2017, 4, 15, 0, 0)},
#  {'Number of fires': 38, 'date': datetime.datetime(2017, 4, 17, 0, 0)},
#  {'Number of fires': 50, 'date': datetime.datetime(2017, 4, 19, 0, 0)},
#  {'Number of fires': 31, 'date': datetime.datetime(2017, 4, 20, 0, 0)},
#  {'Number of fires': 325, 'date': datetime.datetime(2017, 4, 18, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 4, 22, 0, 0)},
#  {'Number of fires': 19, 'date': datetime.datetime(2017, 4, 23, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 4, 25, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 4, 26, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 4, 29, 0, 0)},
#  {'Number of fires': 10, 'date': datetime.datetime(2017, 2, 5, 0, 0)},
#  {'Number of fires': 135, 'date': datetime.datetime(2017, 4, 5, 0, 0)},
#  {'Number of fires': 17, 'date': datetime.datetime(2017, 6, 5, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 12, 3, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 7, 5, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 9, 29, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 10, 9, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 7, 31, 0, 0)},
#  {'Number of fires': 54, 'date': datetime.datetime(2017, 5, 13, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 4, 10, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 8, 10, 0, 0)},
#  {'Number of fires': 31, 'date': datetime.datetime(2017, 5, 5, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 10, 10, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 3, 29, 0, 0)},
#  {'Number of fires': 8, 'date': datetime.datetime(2017, 4, 24, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 6, 7, 0, 0)},
#  {'Number of fires': 13, 'date': datetime.datetime(2017, 9, 5, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 10, 23, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 11, 6, 0, 0)},
#  {'Number of fires': 6, 'date': datetime.datetime(2017, 10, 18, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 10, 21, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 12, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 10, 28, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 8, 11, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 13, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 5, 8, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 9, 12, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 5, 16, 0, 0)},
#  {'Number of fires': 6, 'date': datetime.datetime(2017, 6, 30, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 21, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 25, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 1, 8, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 6, 22, 0, 0)},
#  {'Number of fires': 15, 'date': datetime.datetime(2017, 12, 16, 0, 0)},
#  {'Number of fires': 10, 'date': datetime.datetime(2017, 9, 11, 0, 0)},
#  {'Number of fires': 20, 'date': datetime.datetime(2017, 1, 5, 0, 0)},
#  {'Number of fires': 8, 'date': datetime.datetime(2017, 11, 29, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 2, 8, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 9, 10, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 8, 14, 0, 0)},
#  {'Number of fires': 7, 'date': datetime.datetime(2017, 9, 27, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 10, 12, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 12, 27, 0, 0)},
#  {'Number of fires': 22, 'date': datetime.datetime(2017, 3, 31, 0, 0)},
#  {'Number of fires': 7, 'date': datetime.datetime(2017, 2, 10, 0, 0)},
#  {'Number of fires': 72, 'date': datetime.datetime(2017, 3, 4, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 8, 12, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 5, 11, 0, 0)},
#  {'Number of fires': 31, 'date': datetime.datetime(2017, 11, 30, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 7, 29, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 14, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 10, 20, 0, 0)},
#  {'Number of fires': 18, 'date': datetime.datetime(2017, 4, 16, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 11, 23, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 3, 6, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 11, 14, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 12, 15, 0, 0)},
#  {'Number of fires': 23, 'date': datetime.datetime(2017, 9, 23, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 10, 8, 0, 0)},
#  {'Number of fires': 64, 'date': datetime.datetime(2017, 3, 5, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 5, 7, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 11, 28, 0, 0)},
#  {'Number of fires': 7, 'date': datetime.datetime(2017, 5, 18, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 10, 16, 0, 0)},
#  {'Number of fires': 89, 'date': datetime.datetime(2017, 4, 4, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 6, 13, 0, 0)},
#  {'Number of fires': 9, 'date': datetime.datetime(2017, 4, 6, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 3, 18, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 12, 24, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 11, 21, 0, 0)},
#  {'Number of fires': 18, 'date': datetime.datetime(2017, 3, 10, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 10, 27, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 11, 22, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 1, 6, 0, 0)},
#  {'Number of fires': 8, 'date': datetime.datetime(2017, 1, 10, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 11, 13, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 10, 26, 0, 0)},
#  {'Number of fires': 8, 'date': datetime.datetime(2017, 2, 7, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 10, 15, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 11, 11, 0, 0)},
#  {'Number of fires': 118, 'date': datetime.datetime(2017, 6, 4, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 9, 21, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 9, 26, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 9, 22, 0, 0)},
#  {'Number of fires': 33, 'date': datetime.datetime(2017, 5, 22, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 10, 17, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 9, 20, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 7, 3, 0, 0)},
#  {'Number of fires': 9, 'date': datetime.datetime(2017, 8, 13, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 4, 7, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 1, 7, 0, 0)},
#  {'Number of fires': 6, 'date': datetime.datetime(2017, 6, 20, 0, 0)},
#  {'Number of fires': 8, 'date': datetime.datetime(2017, 10, 3, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 6, 16, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 7, 14, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 6, 18, 0, 0)},
#  {'Number of fires': 114, 'date': datetime.datetime(2017, 10, 5, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 6, 14, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 9, 6, 0, 0)},
#  {'Number of fires': 28, 'date': datetime.datetime(2017, 9, 24, 0, 0)},
#  {'Number of fires': 14, 'date': datetime.datetime(2017, 7, 6, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 12, 11, 0, 0)},
#  {'Number of fires': 102, 'date': datetime.datetime(2017, 5, 15, 0, 0)},
#  {'Number of fires': 11, 'date': datetime.datetime(2017, 2, 6, 0, 0)},
#  {'Number of fires': 2, 'date': datetime.datetime(2017, 6, 10, 0, 0)},
#  {'Number of fires': 4, 'date': datetime.datetime(2017, 5, 26, 0, 0)},
#  {'Number of fires': 17, 'date': datetime.datetime(2017, 3, 26, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 5, 14, 0, 0)},
#  {'Number of fires': 10, 'date': datetime.datetime(2017, 3, 14, 0, 0)},
#  {'Number of fires': 39, 'date': datetime.datetime(2017, 7, 4, 0, 0)},
#  {'Number of fires': 5, 'date': datetime.datetime(2017, 5, 23, 0, 0)},
#  {'Number of fires': 10, 'date': datetime.datetime(2017, 12, 5, 0, 0)},
#  {'Number of fires': 3, 'date': datetime.datetime(2017, 5, 24, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 5, 17, 0, 0)},
#  {'Number of fires': 13, 'date': datetime.datetime(2017, 3, 25, 0, 0)},
#  {'Number of fires': 7, 'date': datetime.datetime(2017, 1, 4, 0, 0)},
#  {'Number of fires': 19, 'date': datetime.datetime(2017, 11, 5, 0, 0)},
#  {'Number of fires': 1, 'date': datetime.datetime(2017, 7, 10, 0, 0)},
#  {'Number of fires': 24, 'date': datetime.datetime(2017, 8, 5, 0, 0)}]

# %% [markdown]
# #### G.Find the ​average surface temperature ​(°C) f​ or each day​. You are required to only display ​average surface temperature (°C)​ ​and ​the date​ in the output.

# %%
# Determine Average surface temperature (°C) for each day

result = fire_collection.aggregate([{"$group": {"_id":"$date", "average_surface_temp": {"$avg":"$surface_temperature_celcius"} } },
                                 { "$project" : { "_id" : 0, "date": "$_id", "average_surface_temp":1 } }])

# print the output
[x for x in result]
# Out:
# [{'average_surface_temp': 60.5, 'date': datetime.datetime(2017, 6, 3, 0, 0)},
#  {'average_surface_temp': 51.5, 'date': datetime.datetime(2017, 8, 3, 0, 0)},
#  {'average_surface_temp': 46.666666666666664,
#   'date': datetime.datetime(2017, 9, 3, 0, 0)},
#  {'average_surface_temp': 38.5, 'date': datetime.datetime(2017, 3, 13, 0, 0)},
#  {'average_surface_temp': 46.0, 'date': datetime.datetime(2017, 3, 15, 0, 0)},
#  {'average_surface_temp': 59.5, 'date': datetime.datetime(2017, 3, 17, 0, 0)},
#  {'average_surface_temp': 65.57142857142857,
#   'date': datetime.datetime(2017, 3, 19, 0, 0)},
#  {'average_surface_temp': 60.925925925925924,
#   'date': datetime.datetime(2017, 3, 28, 0, 0)},
#  {'average_surface_temp': 45.2, 'date': datetime.datetime(2017, 2, 4, 0, 0)},
#  {'average_surface_temp': 53.142857142857146,
#   'date': datetime.datetime(2017, 5, 4, 0, 0)},
#  {'average_surface_temp': 60.75, 'date': datetime.datetime(2017, 8, 4, 0, 0)},
#  {'average_surface_temp': 49.0, 'date': datetime.datetime(2017, 3, 24, 0, 0)},
#  {'average_surface_temp': 46.291666666666664,
#   'date': datetime.datetime(2017, 11, 4, 0, 0)},
#  {'average_surface_temp': 52.69565217391305,
#   'date': datetime.datetime(2017, 12, 4, 0, 0)},
#  {'average_surface_temp': 58.57983193277311,
#   'date': datetime.datetime(2017, 4, 13, 0, 0)},
#  {'average_surface_temp': 61.94444444444444,
#   'date': datetime.datetime(2017, 4, 14, 0, 0)},
#  {'average_surface_temp': 59.57971014492754,
#   'date': datetime.datetime(2017, 4, 15, 0, 0)},
#  {'average_surface_temp': 50.921052631578945,
#   'date': datetime.datetime(2017, 4, 17, 0, 0)},
#  {'average_surface_temp': 54.16, 'date': datetime.datetime(2017, 4, 19, 0, 0)},
#  {'average_surface_temp': 56.58064516129032,
#   'date': datetime.datetime(2017, 4, 20, 0, 0)},
#  {'average_surface_temp': 53.36615384615384,
#   'date': datetime.datetime(2017, 4, 18, 0, 0)},
#  {'average_surface_temp': 54.5, 'date': datetime.datetime(2017, 4, 22, 0, 0)},
#  {'average_surface_temp': 53.89473684210526,
#   'date': datetime.datetime(2017, 4, 23, 0, 0)},
#  {'average_surface_temp': 48.666666666666664,
#   'date': datetime.datetime(2017, 4, 25, 0, 0)},
#  {'average_surface_temp': 34.0, 'date': datetime.datetime(2017, 4, 26, 0, 0)},
#  {'average_surface_temp': 63.0, 'date': datetime.datetime(2017, 4, 29, 0, 0)},
#  {'average_surface_temp': 55.6, 'date': datetime.datetime(2017, 2, 5, 0, 0)},
#  {'average_surface_temp': 56.80740740740741,
#   'date': datetime.datetime(2017, 4, 5, 0, 0)},
#  {'average_surface_temp': 57.529411764705884,
#   'date': datetime.datetime(2017, 6, 5, 0, 0)},
#  {'average_surface_temp': 88.2, 'date': datetime.datetime(2017, 12, 3, 0, 0)},
#  {'average_surface_temp': 50.333333333333336,
#   'date': datetime.datetime(2017, 7, 5, 0, 0)},
#  {'average_surface_temp': 43.0, 'date': datetime.datetime(2017, 9, 29, 0, 0)},
#  {'average_surface_temp': 56.5, 'date': datetime.datetime(2017, 10, 9, 0, 0)},
#  {'average_surface_temp': 47.0, 'date': datetime.datetime(2017, 7, 31, 0, 0)},
#  {'average_surface_temp': 58.611111111111114,
#   'date': datetime.datetime(2017, 5, 13, 0, 0)},
#  {'average_surface_temp': 49.0, 'date': datetime.datetime(2017, 4, 10, 0, 0)},
#  {'average_surface_temp': 41.0, 'date': datetime.datetime(2017, 8, 10, 0, 0)},
#  {'average_surface_temp': 51.70967741935484,
#   'date': datetime.datetime(2017, 5, 5, 0, 0)},
#  {'average_surface_temp': 53.333333333333336,
#   'date': datetime.datetime(2017, 10, 10, 0, 0)},
#  {'average_surface_temp': 51.0, 'date': datetime.datetime(2017, 3, 29, 0, 0)},
#  {'average_surface_temp': 59.375,
#   'date': datetime.datetime(2017, 4, 24, 0, 0)},
#  {'average_surface_temp': 56.0, 'date': datetime.datetime(2017, 6, 7, 0, 0)},
#  {'average_surface_temp': 42.46153846153846,
#   'date': datetime.datetime(2017, 9, 5, 0, 0)},
#  {'average_surface_temp': 38.0, 'date': datetime.datetime(2017, 10, 23, 0, 0)},
#  {'average_surface_temp': 41.5, 'date': datetime.datetime(2017, 11, 6, 0, 0)},
#  {'average_surface_temp': 52.166666666666664,
#   'date': datetime.datetime(2017, 10, 18, 0, 0)},
#  {'average_surface_temp': 51.25,
#   'date': datetime.datetime(2017, 10, 21, 0, 0)},
#  {'average_surface_temp': 44.0, 'date': datetime.datetime(2017, 12, 12, 0, 0)},
#  {'average_surface_temp': 56.0, 'date': datetime.datetime(2017, 10, 28, 0, 0)},
#  {'average_surface_temp': 45.5, 'date': datetime.datetime(2017, 8, 11, 0, 0)},
#  {'average_surface_temp': 60.0, 'date': datetime.datetime(2017, 12, 13, 0, 0)},
#  {'average_surface_temp': 40.0, 'date': datetime.datetime(2017, 5, 8, 0, 0)},
#  {'average_surface_temp': 58.25, 'date': datetime.datetime(2017, 9, 12, 0, 0)},
#  {'average_surface_temp': 39.666666666666664,
#   'date': datetime.datetime(2017, 5, 16, 0, 0)},
#  {'average_surface_temp': 44.333333333333336,
#   'date': datetime.datetime(2017, 6, 30, 0, 0)},
#  {'average_surface_temp': 46.0, 'date': datetime.datetime(2017, 12, 21, 0, 0)},
#  {'average_surface_temp': 54.0, 'date': datetime.datetime(2017, 12, 25, 0, 0)},
#  {'average_surface_temp': 58.0, 'date': datetime.datetime(2017, 1, 8, 0, 0)},
#  {'average_surface_temp': 46.0, 'date': datetime.datetime(2017, 6, 22, 0, 0)},
#  {'average_surface_temp': 57.8, 'date': datetime.datetime(2017, 12, 16, 0, 0)},
#  {'average_surface_temp': 61.3, 'date': datetime.datetime(2017, 9, 11, 0, 0)},
#  {'average_surface_temp': 68.4, 'date': datetime.datetime(2017, 1, 5, 0, 0)},
#  {'average_surface_temp': 60.625,
#   'date': datetime.datetime(2017, 11, 29, 0, 0)},
#  {'average_surface_temp': 63.5, 'date': datetime.datetime(2017, 2, 8, 0, 0)},
#  {'average_surface_temp': 44.0, 'date': datetime.datetime(2017, 9, 10, 0, 0)},
#  {'average_surface_temp': 40.8, 'date': datetime.datetime(2017, 8, 14, 0, 0)},
#  {'average_surface_temp': 49.714285714285715,
#   'date': datetime.datetime(2017, 9, 27, 0, 0)},
#  {'average_surface_temp': 46.0, 'date': datetime.datetime(2017, 10, 12, 0, 0)},
#  {'average_surface_temp': 62.75,
#   'date': datetime.datetime(2017, 12, 27, 0, 0)},
#  {'average_surface_temp': 48.72727272727273,
#   'date': datetime.datetime(2017, 3, 31, 0, 0)},
#  {'average_surface_temp': 43.57142857142857,
#   'date': datetime.datetime(2017, 2, 10, 0, 0)},
#  {'average_surface_temp': 58.44444444444444,
#   'date': datetime.datetime(2017, 3, 4, 0, 0)},
#  {'average_surface_temp': 50.6, 'date': datetime.datetime(2017, 8, 12, 0, 0)},
#  {'average_surface_temp': 58.5, 'date': datetime.datetime(2017, 5, 11, 0, 0)},
#  {'average_surface_temp': 52.41935483870968,
#   'date': datetime.datetime(2017, 11, 30, 0, 0)},
#  {'average_surface_temp': 48.0, 'date': datetime.datetime(2017, 7, 29, 0, 0)},
#  {'average_surface_temp': 70.0, 'date': datetime.datetime(2017, 12, 14, 0, 0)},
#  {'average_surface_temp': 50.0, 'date': datetime.datetime(2017, 10, 20, 0, 0)},
#  {'average_surface_temp': 48.72222222222222,
#   'date': datetime.datetime(2017, 4, 16, 0, 0)},
#  {'average_surface_temp': 58.8, 'date': datetime.datetime(2017, 11, 23, 0, 0)},
#  {'average_surface_temp': 47.0, 'date': datetime.datetime(2017, 3, 6, 0, 0)},
#  {'average_surface_temp': 52.0, 'date': datetime.datetime(2017, 11, 14, 0, 0)},
#  {'average_surface_temp': 39.0, 'date': datetime.datetime(2017, 12, 15, 0, 0)},
#  {'average_surface_temp': 52.73913043478261,
#   'date': datetime.datetime(2017, 9, 23, 0, 0)},
#  {'average_surface_temp': 63.0, 'date': datetime.datetime(2017, 10, 8, 0, 0)},
#  {'average_surface_temp': 56.796875,
#   'date': datetime.datetime(2017, 3, 5, 0, 0)},
#  {'average_surface_temp': 45.0, 'date': datetime.datetime(2017, 5, 7, 0, 0)},
#  {'average_surface_temp': 42.0, 'date': datetime.datetime(2017, 11, 28, 0, 0)},
#  {'average_surface_temp': 44.142857142857146,
#   'date': datetime.datetime(2017, 5, 18, 0, 0)},
#  {'average_surface_temp': 36.0, 'date': datetime.datetime(2017, 10, 16, 0, 0)},
#  {'average_surface_temp': 62.57303370786517,
#   'date': datetime.datetime(2017, 4, 4, 0, 0)},
#  {'average_surface_temp': 41.0, 'date': datetime.datetime(2017, 6, 13, 0, 0)},
#  {'average_surface_temp': 52.22222222222222,
#   'date': datetime.datetime(2017, 4, 6, 0, 0)},
#  {'average_surface_temp': 79.33333333333333,
#   'date': datetime.datetime(2017, 3, 18, 0, 0)},
#  {'average_surface_temp': 32.0, 'date': datetime.datetime(2017, 12, 24, 0, 0)},
#  {'average_surface_temp': 59.0, 'date': datetime.datetime(2017, 11, 21, 0, 0)},
#  {'average_surface_temp': 50.0, 'date': datetime.datetime(2017, 3, 10, 0, 0)},
#  {'average_surface_temp': 50.4, 'date': datetime.datetime(2017, 10, 27, 0, 0)},
#  {'average_surface_temp': 61.5, 'date': datetime.datetime(2017, 11, 22, 0, 0)},
#  {'average_surface_temp': 54.0, 'date': datetime.datetime(2017, 1, 6, 0, 0)},
#  {'average_surface_temp': 48.25, 'date': datetime.datetime(2017, 1, 10, 0, 0)},
#  {'average_surface_temp': 47.0, 'date': datetime.datetime(2017, 11, 13, 0, 0)},
#  {'average_surface_temp': 44.6, 'date': datetime.datetime(2017, 10, 26, 0, 0)},
#  {'average_surface_temp': 43.5, 'date': datetime.datetime(2017, 2, 7, 0, 0)},
#  {'average_surface_temp': 72.66666666666667,
#   'date': datetime.datetime(2017, 10, 15, 0, 0)},
#  {'average_surface_temp': 46.25,
#   'date': datetime.datetime(2017, 11, 11, 0, 0)},
#  {'average_surface_temp': 61.71186440677966,
#   'date': datetime.datetime(2017, 6, 4, 0, 0)},
#  {'average_surface_temp': 40.5, 'date': datetime.datetime(2017, 9, 21, 0, 0)},
#  {'average_surface_temp': 33.0, 'date': datetime.datetime(2017, 9, 26, 0, 0)},
#  {'average_surface_temp': 45.0, 'date': datetime.datetime(2017, 9, 22, 0, 0)},
#  {'average_surface_temp': 54.484848484848484,
#   'date': datetime.datetime(2017, 5, 22, 0, 0)},
#  {'average_surface_temp': 51.6, 'date': datetime.datetime(2017, 10, 17, 0, 0)},
#  {'average_surface_temp': 63.6, 'date': datetime.datetime(2017, 9, 20, 0, 0)},
#  {'average_surface_temp': 64.0, 'date': datetime.datetime(2017, 7, 3, 0, 0)},
#  {'average_surface_temp': 49.0, 'date': datetime.datetime(2017, 8, 13, 0, 0)},
#  {'average_surface_temp': 40.0, 'date': datetime.datetime(2017, 4, 7, 0, 0)},
#  {'average_surface_temp': 30.5, 'date': datetime.datetime(2017, 1, 7, 0, 0)},
#  {'average_surface_temp': 71.16666666666667,
#   'date': datetime.datetime(2017, 6, 20, 0, 0)},
#  {'average_surface_temp': 69.375,
#   'date': datetime.datetime(2017, 10, 3, 0, 0)},
#  {'average_surface_temp': 42.5, 'date': datetime.datetime(2017, 6, 16, 0, 0)},
#  {'average_surface_temp': 41.5, 'date': datetime.datetime(2017, 7, 14, 0, 0)},
#  {'average_surface_temp': 42.0, 'date': datetime.datetime(2017, 6, 18, 0, 0)},
#  {'average_surface_temp': 52.86842105263158,
#   'date': datetime.datetime(2017, 10, 5, 0, 0)},
#  {'average_surface_temp': 53.25, 'date': datetime.datetime(2017, 6, 14, 0, 0)},
#  {'average_surface_temp': 49.0, 'date': datetime.datetime(2017, 9, 6, 0, 0)},
#  {'average_surface_temp': 53.57142857142857,
#   'date': datetime.datetime(2017, 9, 24, 0, 0)},
#  {'average_surface_temp': 51.857142857142854,
#   'date': datetime.datetime(2017, 7, 6, 0, 0)},
#  {'average_surface_temp': 53.0, 'date': datetime.datetime(2017, 12, 11, 0, 0)},
#  {'average_surface_temp': 53.950980392156865,
#   'date': datetime.datetime(2017, 5, 15, 0, 0)},
#  {'average_surface_temp': 47.72727272727273,
#   'date': datetime.datetime(2017, 2, 6, 0, 0)},
#  {'average_surface_temp': 44.0, 'date': datetime.datetime(2017, 6, 10, 0, 0)},
#  {'average_surface_temp': 49.5, 'date': datetime.datetime(2017, 5, 26, 0, 0)},
#  {'average_surface_temp': 56.88235294117647,
#   'date': datetime.datetime(2017, 3, 26, 0, 0)},
#  {'average_surface_temp': 49.0, 'date': datetime.datetime(2017, 5, 14, 0, 0)},
#  {'average_surface_temp': 65.6, 'date': datetime.datetime(2017, 3, 14, 0, 0)},
#  {'average_surface_temp': 50.69230769230769,
#   'date': datetime.datetime(2017, 7, 4, 0, 0)},
#  {'average_surface_temp': 51.2, 'date': datetime.datetime(2017, 5, 23, 0, 0)},
#  {'average_surface_temp': 51.5, 'date': datetime.datetime(2017, 12, 5, 0, 0)},
#  {'average_surface_temp': 40.333333333333336,
#   'date': datetime.datetime(2017, 5, 24, 0, 0)},
#  {'average_surface_temp': 52.0, 'date': datetime.datetime(2017, 5, 17, 0, 0)},
#  {'average_surface_temp': 66.0, 'date': datetime.datetime(2017, 3, 25, 0, 0)},
#  {'average_surface_temp': 46.714285714285715,
#   'date': datetime.datetime(2017, 1, 4, 0, 0)},
#  {'average_surface_temp': 59.36842105263158,
#   'date': datetime.datetime(2017, 11, 5, 0, 0)},
#  {'average_surface_temp': 42.0, 'date': datetime.datetime(2017, 7, 10, 0, 0)},
#  {'average_surface_temp': 56.291666666666664,
#   'date': datetime.datetime(2017, 8, 5, 0, 0)}]
